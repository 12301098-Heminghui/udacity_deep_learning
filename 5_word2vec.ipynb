# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE
import os

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'
#data_root = './raw_text/'
def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    #data = tf.compat.as_str(f.read(f.namelist()[0])).split()
    data = f.read(f.namelist()[0]).encode('utf-8').split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1) # 生成一个随机数，随机数区间为[0, span-1]
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'originated', 'a', 'term', 'as', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['originated', 'anarchism', 'term', 'a', 'term', 'of', 'as', 'originated']

# %% [markdown]
# # Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.654356
# Nearest to with: predate, parasitic, stradella, lez, milan, foreword, revitalization, dba,
# Nearest to be: kahn, alleviate, bledsoe, restrictions, strickland, estimated, plaza, forgave,
# Nearest to have: satyagraha, secretion, cashier, vinci, lcd, apocalyptic, chalcolithic, devising,
# Nearest to most: we, half, recognizably, mailbox, jp, righteous, discrepancy, cort,
# Nearest to that: rationale, yitzhak, highness, piedmont, claremont, raged, saw, headers,
# Nearest to zero: gallen, jehoiachin, badgers, portable, perdition, hoshea, nfs, simplest,
# Nearest to if: insuring, nationals, hangings, exploding, kilmister, borda, herd, mountain,
# Nearest to there: loud, veritas, victim, antibiotics, sachet, reportage, thebes, gnumeric,
# Nearest to state: pennants, kumquat, methylene, nootka, lublin, hephaestus, league, assemblers,
# Nearest to other: microgravity, aubrey, nellis, saronic, urquhart, reaffirmed, eck, hydrate,
# Nearest to his: antidepressant, tenacity, pellucidar, masculinity, mendel, elie, militant, ascends,
# Nearest to three: socially, mysql, utilization, gown, macrocosm, mand, invading, duval,
# Nearest to has: definitive, empiricists, monies, feuds, workshop, christendom, swf, machinima,
# Nearest to years: hindustan, comit, abuser, ido, stephens, telepathic, bitter, fame,
# Nearest to will: bright, auks, hamilton, pastiches, credo, artaxerxes, multiprocessing, agency,
# Nearest to their: exams, colts, retracted, speaks, upload, implied, grape, pioneers,
# Average loss at step 2000: 4.369397
# Average loss at step 4000: 3.865915
# Average loss at step 6000: 3.781630
# Average loss at step 8000: 3.684328
# Average loss at step 10000: 3.618673
# Nearest to with: in, rk, by, rubbish, between, for, gimme, freebase,
# Nearest to be: have, bledsoe, was, sol, been, were, indistinguishable, algirdas,
# Nearest to have: had, has, were, be, are, do, indistinguishable, tiresias,
# Nearest to most: recognizably, more, half, fornication, modification, all, eutyches, macht,
# Nearest to that: which, this, highness, saw, who, qdos, awa, soften,
# Nearest to zero: seven, nine, six, five, eight, four, three, two,
# Nearest to if: insuring, exploding, hangings, borda, cristae, nantes, bolo, reluctantly,
# Nearest to there: it, they, not, rebirth, he, also, antibiotics, ageing,
# Nearest to state: methylene, maus, pennants, nootka, kumquat, cinderella, lublin, aggregates,
# Nearest to other: connectivity, airfield, murky, homerun, nonfiction, cheerfully, usda, hansard,
# Nearest to his: her, their, s, the, its, a, this, jardine,
# Nearest to three: five, six, four, seven, eight, two, nine, zero,
# Nearest to has: had, have, was, is, ramadan, does, are, cheap,
# Nearest to years: telepathic, death, disrupting, fearless, hindustan, facilitator, consist, figures,
# Nearest to will: can, bright, would, hamilton, artaxerxes, courthouse, emedicine, auks,
# Nearest to their: its, his, the, advisors, bellows, easter, upload, this,
# Average loss at step 12000: 3.606082
# Average loss at step 14000: 3.577871
# Average loss at step 16000: 3.408964
# Average loss at step 18000: 3.463906
# Average loss at step 20000: 3.540833
# Nearest to with: between, in, stradella, by, rk, dura, at, relates,
# Nearest to be: have, been, was, by, is, bledsoe, sol, were,
# Nearest to have: had, has, be, were, are, repr, believe, cosmetics,
# Nearest to most: more, eutyches, some, all, recognizably, chapters, enniskillen, fish,
# Nearest to that: which, but, who, eclipsed, raged, awa, however, also,
# Nearest to zero: five, six, four, seven, two, eight, nine, three,
# Nearest to if: when, does, cristae, exploding, bofh, would, insuring, broglie,
# Nearest to there: it, they, he, which, ageing, rebirth, also, abadan,
# Nearest to state: ix, cinderella, kumquat, methylene, nootka, pennants, gears, visible,
# Nearest to other: many, these, connectivity, some, interval, murky, flares, airfield,
# Nearest to his: their, her, its, jardine, the, lindsay, supermarket, antidepressant,
# Nearest to three: four, five, seven, six, two, eight, one, nine,
# Nearest to has: had, was, have, is, does, concomitant, almoravids, divina,
# Nearest to years: telepathic, fearless, disrupting, death, facilitator, nada, usd, mi,
# Nearest to will: can, would, could, bright, must, to, may, oriente,
# Nearest to their: its, his, her, the, dependent, advisors, some, podium,
# Average loss at step 22000: 3.505697
# Average loss at step 24000: 3.490737
# Average loss at step 26000: 3.482484
# Average loss at step 28000: 3.485187
# Average loss at step 30000: 3.501537
# Nearest to with: between, rubbish, into, by, for, in, barron, vehicular,
# Nearest to be: have, been, bledsoe, is, kom, algirdas, were, refer,
# Nearest to have: had, has, were, be, are, believe, repr, cosmetics,
# Nearest to most: more, eutyches, atonal, chapters, all, reverberation, some, infringes,
# Nearest to that: which, this, however, awa, saw, lance, compelling, qdos,
# Nearest to zero: five, eight, seven, four, six, nine, three, two,
# Nearest to if: when, does, cristae, but, would, could, though, nantes,
# Nearest to there: it, they, he, often, denied, still, not, which,
# Nearest to state: ix, cinderella, remember, kumquat, aggregates, nootka, messerschmitt, flatted,
# Nearest to other: these, connectivity, some, murky, many, such, different, nonfiction,
# Nearest to his: her, their, its, the, s, my, lindsay, jardine,
# Nearest to three: five, four, two, seven, six, eight, nine, one,
# Nearest to has: had, have, was, is, almoravids, igneous, squirrels, enlarged,
# Nearest to years: days, telepathic, mi, schenectady, consist, feet, fearless, death,
# Nearest to will: would, can, could, must, may, should, bright, shall,
# Nearest to their: its, his, the, her, these, dependent, advisors, some,
# Average loss at step 32000: 3.502366
# Average loss at step 34000: 3.497131
# Average loss at step 36000: 3.454022
# Average loss at step 38000: 3.303146
# Average loss at step 40000: 3.429043
# Nearest to with: between, rubbish, stradella, rk, barron, by, wikis, when,
# Nearest to be: have, been, bledsoe, is, by, are, was, were,
# Nearest to have: had, has, were, be, are, fluids, romany, igneous,
# Nearest to most: more, many, eutyches, surmised, some, all, enniskillen, chapters,
# Nearest to that: which, this, however, who, because, if, compelling, feldspar,
# Nearest to zero: seven, five, nine, eight, three, six, two, four,
# Nearest to if: when, is, where, because, cristae, that, does, can,
# Nearest to there: it, they, he, which, now, often, usually, denied,
# Nearest to state: government, statue, ix, remember, cinderella, flatted, kashima, fly,
# Nearest to other: different, various, primitive, their, nol, cdg, some, nme,
# Nearest to his: their, her, its, my, the, s, your, soir,
# Nearest to three: four, seven, five, two, six, eight, nine, zero,
# Nearest to has: had, have, was, is, almoravids, lenat, eastman, epicureanism,
# Nearest to years: days, telepathic, feet, schenectady, decades, year, disrepair, times,
# Nearest to will: can, would, could, must, may, should, might, cannot,
# Nearest to their: its, his, her, the, dependent, these, any, other,
# Average loss at step 42000: 3.434007
# Average loss at step 44000: 3.454506
# Average loss at step 46000: 3.451548
# Average loss at step 48000: 3.360491
# Average loss at step 50000: 3.384326
# Nearest to with: between, rubbish, infogrames, barron, nssdc, while, vehicular, by,
# Nearest to be: have, been, were, being, was, are, bledsoe, is,
# Nearest to have: had, has, were, be, are, foix, igneous, who,
# Nearest to most: more, many, eutyches, some, less, enniskillen, fiberglass, wegener,
# Nearest to that: which, however, awa, raged, but, eightfold, warranted, this,
# Nearest to zero: five, four, seven, six, eight, nine, three, two,
# Nearest to if: when, where, although, unless, can, could, should, though,
# Nearest to there: they, it, he, now, denied, dalglish, she, which,
# Nearest to state: statue, government, flatted, ry, ix, cinderella, pedophilia, remember,
# Nearest to other: different, many, various, some, these, primitive, grocery, several,
# Nearest to his: their, her, its, my, the, him, soir, your,
# Nearest to three: four, six, seven, two, eight, five, nine, zero,
# Nearest to has: had, have, was, is, almoravids, eastman, having, stipulate,
# Nearest to years: days, months, decades, times, year, hours, feet, telepathic,
# Nearest to will: would, could, can, may, must, should, might, cannot,
# Nearest to their: its, his, her, the, these, dependent, dissociative, some,
# Average loss at step 52000: 3.436735
# Average loss at step 54000: 3.420078
# Average loss at step 56000: 3.439458
# Average loss at step 58000: 3.393822
# Average loss at step 60000: 3.397436
# Nearest to with: between, by, in, barron, freebase, when, polytechnic, rubbish,
# Nearest to be: been, have, bledsoe, was, become, were, is, being,
# Nearest to have: had, has, be, were, are, provide, include, tend,
# Nearest to most: more, many, some, eutyches, all, use, entourage, less,
# Nearest to that: which, this, however, what, there, who, generally, reptilian,
# Nearest to zero: five, four, eight, seven, six, nine, three, two,
# Nearest to if: when, where, though, then, since, unless, should, although,
# Nearest to there: they, it, now, he, this, she, dalglish, still,
# Nearest to state: government, statue, ry, kashima, cinderella, flatted, states, sealing,
# Nearest to other: various, many, different, several, some, grocery, others, multiple,
# Nearest to his: her, their, my, its, the, soir, him, supermarket,
# Nearest to three: four, five, six, eight, seven, two, nine, one,
# Nearest to has: had, have, was, is, having, almoravids, lenat, chiropractors,
# Nearest to years: days, months, decades, times, hours, year, mi, feet,
# Nearest to will: would, could, can, may, must, should, might, cannot,
# Nearest to their: its, his, her, the, our, these, my, your,
# Average loss at step 62000: 3.235570
# Average loss at step 64000: 3.258444
# Average loss at step 66000: 3.403984
# Average loss at step 68000: 3.394055
# Average loss at step 70000: 3.361512
# Nearest to with: between, rubbish, while, noc, in, including, stradella, when,
# Nearest to be: been, have, being, were, is, bledsoe, become, macos,
# Nearest to have: had, has, were, are, be, include, igneous, tend,
# Nearest to most: more, some, many, less, all, eutyches, use, entourage,
# Nearest to that: which, however, this, what, but, therefore, predestination, demesne,
# Nearest to zero: five, six, eight, four, seven, nine, two, three,
# Nearest to if: when, where, though, unless, since, thus, because, while,
# Nearest to there: they, it, now, she, he, still, dalglish, denied,
# Nearest to state: government, states, statue, ry, cinderella, remember, spider, habeas,
# Nearest to other: many, various, some, several, grocery, multiple, these, different,
# Nearest to his: her, their, its, my, your, the, our, pickens,
# Nearest to three: four, five, six, two, seven, eight, nine, zero,
# Nearest to has: had, have, was, is, lenat, almoravids, although, igneous,
# Nearest to years: days, decades, months, times, hours, year, weeks, feet,
# Nearest to will: would, could, may, can, must, should, might, cannot,
# Nearest to their: its, his, her, the, my, your, these, our,
# Average loss at step 72000: 3.375238
# Average loss at step 74000: 3.349978
# Average loss at step 76000: 3.318296
# Average loss at step 78000: 3.351905
# Average loss at step 80000: 3.379314
# Nearest to with: between, rubbish, stradella, barron, infogrames, including, when, by,
# Nearest to be: been, have, being, become, bledsoe, was, easily, were,
# Nearest to have: had, has, are, were, be, include, having, tend,
# Nearest to most: more, many, some, less, wegener, particularly, all, entourage,
# Nearest to that: which, however, this, but, womanhood, where, woodcuts, vault,
# Nearest to zero: five, eight, seven, four, six, nine, three, two,
# Nearest to if: when, though, where, since, unless, because, although, before,
# Nearest to there: they, it, he, she, now, denied, still, usually,
# Nearest to state: government, statue, city, states, remember, cinderella, ry, flatted,
# Nearest to other: various, several, grocery, others, many, different, retaken, mafiosi,
# Nearest to his: her, their, my, its, your, our, the, soir,
# Nearest to three: four, six, two, five, seven, eight, nine, zero,
# Nearest to has: had, have, is, was, since, having, although, almoravids,
# Nearest to years: days, decades, months, times, hours, year, minutes, weeks,
# Nearest to will: would, could, must, can, may, should, might, cannot,
# Nearest to their: its, his, her, our, my, your, these, the,
# Average loss at step 82000: 3.410709
# Average loss at step 84000: 3.410893
# Average loss at step 86000: 3.391270
# Average loss at step 88000: 3.350570
# Average loss at step 90000: 3.363377
# Nearest to with: between, barron, by, stradella, rubbish, in, radha, licences,
# Nearest to be: been, have, become, being, is, refer, bledsoe, produce,
# Nearest to have: had, has, were, are, be, having, include, provide,
# Nearest to most: more, some, many, less, particularly, especially, eutyches, wegener,
# Nearest to that: which, however, what, but, therefore, predestination, this, qdos,
# Nearest to zero: five, seven, eight, six, nine, four, three, u,
# Nearest to if: when, where, though, since, unless, before, although, thus,
# Nearest to there: they, it, he, she, now, sometimes, still, we,
# Nearest to state: government, city, statue, states, cinderella, habeas, zeitung, flatted,
# Nearest to other: various, grocery, different, retaken, several, theological, sheeana, many,
# Nearest to his: her, their, its, my, your, our, the, s,
# Nearest to three: five, two, four, eight, seven, six, nine, one,
# Nearest to has: had, have, is, was, having, contains, since, igneous,
# Nearest to years: days, decades, months, times, hours, year, minutes, weeks,
# Nearest to will: would, must, could, can, may, should, might, cannot,
# Nearest to their: its, his, her, your, our, my, the, formalisms,
# Average loss at step 92000: 3.397504
# Average loss at step 94000: 3.250078
# Average loss at step 96000: 3.360240
# Average loss at step 98000: 3.242743
# Average loss at step 100000: 3.358192
# Nearest to with: between, barron, rubbish, including, behavioral, using, rationalist, lovecraftian,
# Nearest to be: been, have, become, being, is, bledsoe, are, refer,
# Nearest to have: had, has, are, were, be, contain, include, provide,
# Nearest to most: more, less, especially, particularly, some, many, entourage, use,
# Nearest to that: which, however, what, but, who, therefore, gris, headers,
# Nearest to zero: five, four, seven, eight, six, nine, three, two,
# Nearest to if: when, though, where, unless, before, thus, since, because,
# Nearest to there: they, it, he, vicars, still, now, we, she,
# Nearest to state: government, statue, states, ry, ix, city, flatted, cinderella,
# Nearest to other: various, others, different, several, including, grocery, retaken, older,
# Nearest to his: her, their, my, its, the, your, our, s,
# Nearest to three: two, six, seven, four, five, eight, nine, one,
# Nearest to has: had, have, was, is, contains, since, includes, having,
# Nearest to years: days, decades, months, hours, year, times, weeks, minutes,
# Nearest to will: would, must, could, can, should, may, might, cannot,
# Nearest to their: its, his, her, your, the, our, these, my,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---
